# %%
from rift_zones import *

# Sliced sine wave just for a quick test
num_points = 100
x_start = 0
x_end = 15000
amplitude = 3000
frequency = 0.001

x_values = np.linspace(x_start, x_end, num_points) - 2000
y_values = 1500 + amplitude * np.sin(frequency * x_values) + amplitude

pos_df = pd.DataFrame({
    'pos_x': x_values,
    'pos_y': y_values,
})

pos_df['pos_x'] = pos_df['pos_x'].astype(int)
pos_df['pos_y'] = pos_df['pos_y'].astype(int)

pos_df = pos_df.iloc[60:72]

show_zone(pos_df=pos_df, fig_size=(10, 10))

# %%
assign_zone_names(df=pos_df)
# Out:
#     pos_x  pos_y                          zone_name
# 60   7090   6668  Blue Side Mid Outside Outer Tower
# 61   7242   6956  Blue Side Mid Outside Outer Tower
# 62   7393   7188                  Mid Lane (Center)
# 63   7545   7358                  Mid Lane (Center)
# 64   7696   7463                  Mid Lane (Center)
# 65   7848   7499                  Mid Lane (Center)
# 66   8000   7468                  Mid Lane (Center)
# 67   8151   7368                  Mid Lane (Center)
# 68   8303   7202                     Bot Line Brush
# 69   8454   6975                     Bot Line Brush
# 70   8606   6690                    Bot Mid River 1
# 71   8757   6356                    Bot Mid River 1

# %%
from zone_names import *
len(rift_zones)
# Out:
# 151
